# %% [markdown]
# <a href="https://colab.research.google.com/github/Vishal372006/AI-Assignment/blob/main/Vishal%20Patel%20.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt

# %%
y_salary =[20,30,40,50]
x_cgpa =[2,3,4,5]

# %%
plt.plot(x_cgpa,y_salary,"o-g")
plt.xlabel("CGPA")
plt.ylabel("salary")
plt.title("CGPA and Salary Distribution")
plt.show()
